# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv('Data\weight_height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
females = df.loc[ df['Gender'] == 'Female'].copy()
females.head()
# Out:
#       Gender     Height      Weight
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407

# %%
data = females['Height']

# %% [markdown]
# ### 1. between 55.0 and 56.0 inches = ~0.15%

# %%
low_end = 55.0
high_end = 56.0

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(x=data, stat='density',kde=True)
ax.set_title('Distribution of Female Height')
ax.axvline(low_end, color= 'black')
ax.axvline(high_end, color ='black')
ax.axvspan(low_end, high_end, color ='yellow', zorder = 0);

# %%
mean = np.mean(data)
std = np.std(data)
min = np.min(data)
max = np.max(data)

# %%
## we subtract to find the probability of a value occurring in the range
stats.norm.cdf(high_end, loc=mean,scale=std) - stats.norm.cdf(low_end,loc=mean, scale=std)
# Out:
# 0.0015043054289559745

# %% [markdown]
# ### 2. is less than 5 feet (60 in) = ~8.42%

# %%
low_end = data.min()
high_end = 60.0

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(x=data, stat='density',kde=True)
ax.set_title('Distribution of Female Height')
ax.axvline(low_end, color= 'black')
ax.axvline(high_end, color ='black')
ax.axvspan(low_end, high_end, color ='yellow', zorder = 0);

# %%
## we subtract to find the probability of a value occurring in the range
stats.norm.cdf(high_end, loc=mean,scale=std) - stats.norm.cdf(low_end,loc=mean, scale=std)
# Out:
# 0.0842353831336436

# %% [markdown]
# ### 2. 3. is greater than the mean = ~49.98%

# %%
low_end = data.mean()
high_end = data.max()

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(x=data, stat='density',kde=True)
ax.set_title('Distribution of Female Height')
ax.axvline(low_end, color= 'black')
ax.axvline(high_end, color ='black')
ax.axvspan(low_end, high_end, color ='yellow', zorder = 0);

# %%
## we subtract to find the probability of a value occurring in the range
stats.norm.cdf(high_end, loc=mean,scale=std) - stats.norm.cdf(low_end,loc=mean, scale=std)
# Out:
# 0.49983515925093835
